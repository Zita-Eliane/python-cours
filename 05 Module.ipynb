# %% [markdown]
# # Module

# %% [markdown]
# ## Le mot clé import

# %%
import math
import platform
import datetime

print(f"{math.pi:.5f}, {math.fabs(-18)}")
print(platform.uname().node, platform.system())

now = datetime.date.today()
print(now)

print(now.strftime("%d/%m/%Y"))
# Out:
# 3.14159, 18.0
# MacBook-Pro-de-Nicolas.local Darwin
# 2022-10-27
# 27/10/2022

# %% [markdown]
# ## Mot clé from

# %%
from pandas import DataFrame

index = ["Population en Millions", "Nb Voiture en Millions"]
data = {
         "France": pd.Series([67.5, 39], index=index),
         "Allemagne": pd.Series([83.0, 46],index=index),
    }

df = DataFrame(data)
df
# Out:
#                         France  Allemagne
# Population en Millions    67.5       83.0
# Nb Voiture en Millions    39.0       46.0

# %% [markdown]
# ## Mot clé as

# %%
import matplotlib.pyplot as plt
import numpy as np

data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('a')
plt.ylabel('b')
plt.show()
